# %%
a = 15
b = 10

print("Addition: ",a+b)
print("Subtraction: ",a-b)
print("Multiplication: ",a*b)
print("Division: ",a/b)
# Out:
# Addition:  25
# Subtraction:  5
# Multiplication:  150
# Division:  1.5

# %%
s = input("Enter your name: ")
print(f"Welcome, {s}!")
# Out:
# Welcome, Rishabh!

# %%
a = int(input("Enter your age: "))
print(f"You are {a} years old.")
# Out:
# You are 50 years old.

# %%
a = float(input("Enter num1: "))
b = float(input("Enter num2: "))

print("Average: ",(a+b)/2)
# Out:
# Average:  74.94

# %%
a = 15
b = 4

print(a/b)
print(a//b)
print(a%b)
# Out:
# 3.75
# 3
# 3

# %%
a = 100
b = 100.5
c = 'python'
d = False

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x = 10
y = 25

x,y = y,x

print(x)
print(y)
# Out:
# 25
# 10

# %%
a = 25
print(type(a))

a = 'hello'
print(type(a))

a = ['hello', 25, 'bye']
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>

# %%
c = float(input("Enter celsius temperature: "))

f = (c * 9/5) + 32

print("Fahrenheit Temp: ",f)
# Out:
# Fahrenheit Temp:  77.0

# %%
l = int(input("Enter rectangle length: "))
w = int(input("Enter rectangle width: "))

print("Area: ",l*w)
print("Perimeter: ",2+(l*w))
# Out:
# Area:  25
# Perimeter:  27

# %%
p = int(input("Enter principal: "))
r = int(input("Enter Rate: "))
t = int(input("Enter Time: "))

print("Simple Interest: ",(p*r*t)/100)
# Out:
# Simple Interest:  120.0

# %%
r = int(input("Enter radius: "))

print("Circumference: ",2*3.14*r)
print("Area: ",3.14*r**2)
# Out:
# Circumference:  31.400000000000002
# Area:  78.5

# %%
S = int(input("Seconds: "))

h = S//3600
m = (S%3600)//60
s = (S%60)

print("Hours: ",h)
print("Minutes: ",m)
print("Second: ",s)
# Out:
# Hours:  3
# Minutes:  23
# Second:  55

# %%
s1 = int(input("Enter marks: "))
s2 = int(input("Enter marks: "))
s3 = int(input("Enter marks: "))
s4 = int(input("Enter marks: "))
s5 = int(input("Enter marks: "))

t = s1+s2+s3+s4+s5

print("Total: ",t)
print("Percentage: ",t/5)
# Out:
# Total:  312
# Percentage:  62.4

# %%
f = input("Enter First name: ")
l = input("Enter Last name: ")

print("Full Name: ",f+" "+l)
# Out:
# Full Name:  Rishabh Poddar

# %%
k = int(input("Enter Kilometer: "))

print("Centimeters: ",k*100000)
print("Meters: ",k*1000)
# Out:
# Centimeters:  50000000
# Meters:  500000

# %%
r = int(input("Enter rupees: "))

note500 = r // 500
r = r % 500

note200 = r // 200
r = r % 200

note100 = r // 100
r = r % 100

print("500 notes:", note500)
print("200 notes:", note200)
print("100 notes:", note100)
print("Remaining amount:", r)
# Out:
# 500 notes: 0
# 200 notes: 1
# 100 notes: 0
# Remaining amount: 50

# %%
i = int(input("Enter integer: "))

print("square: ",i**2)
print("cube: ",i**3)
# Out:
# square:  2500
# cube:  125000

# %%
print(f"{"*"*20}\nStudent Report\n{'*'*20}")

n = input("Enter name: ")
a = int(input("Enter age: "))
c = input("Enter city: ")

print("Name: ",n)
print("Age: ",a)
print("City: ",c)

print("*"*20)
# Out:
# ********************
# Student Report
# ********************
# Name:  Rishabh
# Age:  20
# City:  Delhi
# ********************

# %%
print(f"{"="*20}\nSTUDENT CARD\n{'='*20}")

n = input("Enter name: ")
a = int(input("Enter age: "))
c = input("Enter college: ")
d = input("Enter course: ")

print("Name: ",n)
print("Age: ",a)
print("College: ",c)
print("Course: ",d)

print("="*20)
# Out:
# ====================
# STUDENT CARD
# ====================
# Name:  Rishabh
# Age:  21
# College:  IITM college of enginnering
# Course:  bca
# ====================
