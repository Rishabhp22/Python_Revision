# %%
import pandas as pd

marks = pd.Series([85, 72, 91, 68])

print(marks)
# Out:
# 0    85
# 1    72
# 2    91
# 3    68
# dtype: int64

# %%
marks = pd.Series(
    [85, 72, 91],
    index=["Aman", "Rahul", "Rohit"]
)

# %%
data = {
    "Name": ["Aman", "Rahul", "Rohit"],
    "Marks": [85, 72, 91],
    "Age": [20, 21, 20]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Marks  Age
# 0   Aman     85   20
# 1  Rahul     72   21
# 2  Rohit     91   20

# %%
marks = pd.Series([10,20,30,40,50])
marks
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
marks.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
marks.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
marks.dtype
# Out:
# dtype('int64')

# %%
city = pd.Series([25,30,22,28],index = ['Delhi','Mumbai','Pune','Jaipur'])
city
# Out:
# Delhi     25
# Mumbai    30
# Pune      22
# Jaipur    28
# dtype: int64

# %%
data = {
    'Name':['A','B','C','D'],
    'Age':[20,21,19,20],
    'Marks':[85,72,91,68]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Age  Marks
# 0    A   20     85
# 1    B   21     72
# 2    C   19     91
# 3    D   20     68

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.dtypes
# Out:
# Name     object
# Age       int64
# Marks     int64
# dtype: object

# %%
df['Passed'] = df['Marks'] >= 40

# %%
df
# Out:
#   Name  Age  Marks  Passed
# 0    A   20     85    True
# 1    B   21     72    True
# 2    C   19     91    True
# 3    D   20     68    True

# %%
df['Name']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: object

# %%
df[["Name", "Marks"]]
# Out:
#   Name  Marks
# 0    A     85
# 1    B     72
# 2    C     91
# 3    D     68

# %%
df.loc[len(df)] = ['E',22,65,True]

# %%
df
# Out:
#   Name  Age  Marks  Passed
# 0    A   20     85    True
# 1    B   21     72    True
# 2    C   19     91    True
# 3    D   20     68    True
# 4    E   22     65    True

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["A", "B", "C", "D", "E"],
    "Age": [20, 21, 19, 22, 20],
    "Marks": [85, 72, 91, 68, 95]
})

# %%
df.iloc[0]
# Out:
# Name      A
# Age      20
# Marks    85
# Name: 0, dtype: object

# %%
df.iloc[2]
# Out:
# Name      C
# Age      19
# Marks    91
# Name: 2, dtype: object

# %%
df.iloc[0:3]
# Out:
#   Name  Age  Marks
# 0    A   20     85
# 1    B   21     72
# 2    C   19     91

# %%
df.iloc[0,2]
# Out:
# np.int64(85)

# %%
df.iloc[2, 1]
# Out:
# np.int64(19)

# %%
df.loc[0]
# Out:
# Name      A
# Age      20
# Marks    85
# Name: 0, dtype: object

# %%
df.loc[0, "Name"]
# Out:
# 'A'

# %%
df.loc[0, ["Name", "Marks"]]
# Out:
# Name      A
# Marks    85
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name      A
# Age      20
# Marks    85
# Name: 0, dtype: object

# %%
df.loc[3]
# Out:
# Name      D
# Age      22
# Marks    68
# Name: 3, dtype: object

# %%
df["Marks"].iloc[0]
# Out:
# np.int64(85)

# %%
df['Name'].loc[4]
# Out:
# 'E'

# %%
df.iloc[:3]
# Out:
#   Name  Age  Marks
# 0    A   20     85
# 1    B   21     72
# 2    C   19     91

# %%
df['Name'].loc[4]
# Out:
# 'E'

# %%
df.loc[:2, ['Name','Marks']]
# Out:
#   Name  Marks
# 0    A     85
# 1    B     72
# 2    C     91

# %%
df.loc[df["Marks"] == 95]
# Out:
#   Name  Age  Marks
# 4    E   20     95
